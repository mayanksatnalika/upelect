# %%
import time 
from dateutil import parser
import matplotlib.pyplot as plt
import calendar
import pymongo
import datetime 
import pytz 
import json
import urllib2
import json
import tweepy
from pymongo import MongoClient
import json
import requests
import pymongo
import unicodedata
from sendEmail import msgme
import pandas as pd

now = datetime.datetime.now(pytz.timezone('Asia/Calcutta')) # you could pass `timezone` object here
now = now.date()
now =  now.strftime('%Y-%m-%d')
now = str(now)
print 'today is ',now
uri = 'mongodb://root:root@ds139979.mlab.com:39979/upelect'
consumer_key = "POA1eXAkYisz3kBRdcmjeBcha"
consumer_secret = "Ol97n9dfJcSiHvxUmPfRoR7QcLBMzuM5MdOrG36dBuNyT2EzNw"
access_token = "354671169-ROmqMvVamNyggX9hqNzlpqhTgc6AkCOpT6bsjodA"
access_secret = "RqlakpclhdjQzijYhaSfqqK0Yhzv3AZe6RdQggdms8sYn"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.secure = True
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

count  = 0
class MyStreamListener(tweepy.StreamListener):
    print('func called')



    def on_data(self, data):
        global count

        # Decode JSON
        datajson = json.loads(data)
        client = pymongo.MongoClient(uri)
        db = client.upelect
        #print datajson 
        upnames =  ['up','UP','Uttar','Pradesh','uttar','pradesh','election','uttarpradesh',
                    '@uttarpradesh', '#uttarpradesh','#UttarPradesh','#UttarPradeshelection','uttar pradesh election']
        if 'text'  in datajson:
            if(any(wrd in  datajson['text'] for wrd in upnames) and datajson['lang'] == 'en'):

                dicti = {}
                dicti['tweet_text'] = datajson['text']
                dicti['date'] = now
                print dicti
                myjson = json.dumps(dicti)
                c = json.loads(myjson)


                #db.upradesh_tweets.insert_one(c)
                print("inserted")
                count +=1
                if count%5 == 0:
                    msgstr = 'current count is '+ str(count)
                    msgme(msgstr)

            

    def on_error(self, status):

        print status


myStreamListener = MyStreamListener()

myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

#myStream.filter(track =
#                ['#uttarpradesh','#UttarPradesh','#UttarPradeshelection',
#                 'uttar pradesh election','@BJP4UP','@Samajwadi_Party', '@OfficeOfRG', '@AmitShah','@yadavakhilesh','@BSP4India','#bsp']
#               )
 
myStream.filter(track =
                ['@BJP4UP', '@narendramodi','@BJP4India',
                 '@yadavakhilesh', '@Samajwadi_Party' ,
                  ,'@OfficeOfRG','@UPCC_Official','@INCIndia',
                 '@BSP4India','#bsp',
                ]
               )
# Out:
# today is  2017-02-13
# func called
# {'date': '2017-02-13', 'tweet_text': u'@narendramodi help us get rid of gunda #kaamboltahai @yadavakhilesh \n\n#upelections2017 https://t.co/APMwWaicop'}
# inserted
# {'date': '2017-02-13', 'tweet_text': u"RT @bhaumik09: @GNFCLTD shows how it's done! #CashlessEconomy https://t.co/IfXhyRlDPi @ParagDr @narendramodi @Swamy39 @CMOGuj @drrajivgupta\u2026"}
# inserted
# {'date': '2017-02-13', 'tweet_text': u"RT @KunalChoudhary_: Some Glimpses of @INCIndia VP Shri #RahulGandhi's Road Show in #Uttarakhand. @OfficeOfRG @vidyarthee https://t.co/Mk07\u2026"}
# inserted
# {'date': '2017-02-13', 'tweet_text': u'@BJP4UP @kpmaurya1 @narendramodi why so much delay.waiting for half n hour..'}
# inserted
# {'date': '2017-02-13', 'tweet_text': u'RT @NehaGup32856393: @AnjanaS17532387 @narendramodi @YouTube \nValentine Day is an insult to pure love of parents #Tomorrow_ParentsWorshipDay'}
# inserted
# email sent
# {'date': '2017-02-13', 'tweet_text': u'RT @ukshahi: On this #MondayMorning ,I wish nd pray for massive victory of @BJP4India in UP.  Criminal Raj &amp; misrule of\u2026 '}
# inserted
# {'date': '2017-02-13', 'tweet_text': u'RT @LootedbyNSEL: @NSELduped @narendramodi @FinMinIndia @adhia03 @dir_ed Jignesh Shah of NSEL rules India @SushmaSwaraj @DrGarekar\u2026 '}
# inserted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a4399ba7da93> in <module>()
#      87 myStream.filter(track =
#      88                 ['@BJP4UP','@Samajwadi_Party' , '@narendramodi','@yadavakhilesh','@BSP4India','#bsp','@OfficeOfRG',
# ---> 89                  '@UPCC_Official','@INCIndia']
#      90                )
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding)
#     314         self.body = urlencode_noplus(self.parameters)
#     315         self.parameters['delimited'] = 'length'
# --> 316         self._start(async)
#     317
#     318     def disconnect(self):
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     235             Thread(target=self._run).start()
#     236         else:
# --> 237             self._run()
#     238
#     239     def on_closed(self, resp):
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     171                     self.snooze_time = self.snooze_time_step
#     172                     self.listener.on_connect()
# --> 173                     self._read_loop(resp)
#     174             except (timeout, ssl.SSLError) as exc:
#     175                 # If it's not time out treat it like any other exception
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     212             c = '\n'
#     213             while c == '\n' and self.running and not resp.isclosed():
# --> 214                 c = resp.read(1)
#     215             delimited_string = c
#     216
#
# /home/fsftn/anaconda2/lib/python2.7/httplib.pyc in read(self, amt)
#     586
#     587         if self.chunked:
# --> 588             return self._read_chunked(amt)
#     589
#     590         if amt is None:
#
# /home/fsftn/anaconda2/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     628         while True:
#     629             if chunk_left is None:
# --> 630                 line = self.fp.readline(_MAXLINE + 1)
#     631                 if len(line) > _MAXLINE:
#     632                     raise LineTooLong("chunk size")
#
# /home/fsftn/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /home/fsftn/anaconda2/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     754                     "non-zero flags not allowed in calls to recv() on %s" %
#     755                     self.__class__)
# --> 756             return self.read(buflen)
#     757         else:
#     758             return self._sock.recv(buflen, flags)
#
# /home/fsftn/anaconda2/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     641                 v = self._sslobj.read(len, buffer)
#     642             else:
# --> 643                 v = self._sslobj.read(len)
#     644             return v
#     645         except SSLError as x:
#
# KeyboardInterrupt:
